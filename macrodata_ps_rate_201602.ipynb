# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ls
# Out:
# 62-1TEST-20180423_021754.csv
# Untitled.ipynb
# macrodata/
# macrodata_2.xlsx
# macrodata_201304.csv
# macrodata_201304.ipynb
# macrodata_201404.csv
# macrodata_201404.ipynb
# macrodata_201404_1monthdelay.csv
# macrodata_201404_1monthdelay.ipynb
# macrodata_201602.csv
# macrodata_201602.ipynb
# macrodata_ps_rate_201602.csv
# macrodata_rate_1month_201602.csv
# macrodata_rate_1month_201602.ipynb
# macrodata_rate_201602.csv
# macrodata_rate_201602.ipynb
# macrodata_rate_201602のコピー.csv
# macrodata_rate_kettei_201602.csv
# macrodata_rate_kettei_201602.ipynb
# macrodata_準備中.xlsx

# %%
df = pd.read_csv('macrodata_ps_rate_201602.csv')
df.head()
# Out:
#    ess_send_cnt  crs_send_cnt  ess_rep_cnt  crs_rep_cnt  total_gross_kettei  \
# 0       70269.0       72615.0       9481.0       4900.0               462.0
# 1       76890.0       63383.0      10231.0       4849.0               566.0
# 2       76307.0       61399.0       9865.0       5377.0               512.0
# 3       77604.0       51334.0      10234.0       4463.0               450.0
# 4       89683.0       61264.0      12304.0       6046.0               595.0
#
#    ess_gross_kettei  crs_gross_kettei  ess_job_cnt  crs_job_cnt  uhs_cnt  \
# 0             303.0             159.0      11013.0       1717.0  11480.0
# 1             400.0             166.0       9999.0       2081.0  11913.0
# 2             339.0             173.0      14527.0       1655.0  11697.0
# 3             322.0             128.0       9739.0       1549.0  11527.0
# 4             426.0             169.0      14891.0       2056.0  13315.0
#
#       ...       crs_uhs_kettei_rate  login_act_ps_c_rate  ess_ps_rep_rate  \
# 0     ...                  0.044426             0.767081         0.134924
# 1     ...                  0.046525             0.764076         0.133060
# 2     ...                  0.045962             0.774797         0.129280
# 3     ...                  0.039963             0.719820         0.131875
# 4     ...                  0.040143             0.764258         0.137194
#
#    crs_ps_rep_rate  ess_ps_rep_c_rate  crs_ps_rep_c_rate  \
# 0         0.067479           0.208305           0.120424
# 1         0.076503           0.210056           0.128459
# 2         0.087575           0.210799           0.135713
# 3         0.086940           0.211345           0.132805
# 4         0.098688           0.220290           0.150253
#
#    ps_login_act_c_cover_rate  ess_ps_login_act_c_cover_rate  \
# 0                   0.767081                       0.505075
# 1                   0.764076                       0.529628
# 2                   0.774797                       0.519196
# 3                   0.719820                       0.531689
# 4                   0.764258                       0.566485
#
#    crs_ps_login_act_c_cover_rate  uhs_ps_rate
# 0                       0.495746     0.774216
# 1                       0.470208     0.769915
# 2                       0.489229     0.800205
# 3                       0.409117     0.770365
# 4                       0.442226     0.800601
#
# [5 rows x 33 columns]

# %%
plt.figure(figsize=(30, 30)) #heatmap size
plt.rcParams["font.size"] = 15
plt.tick_params(labelsize=15)
sns.heatmap(df.corr(), annot=True,  cmap='plasma', linewidths=1)
